# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch_optimizer as optim
import torch.utils.data as data
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import math
import shutil

#Advanced Pytorchから
import glob
import os.path as osp
import random
import json
from PIL import Image
from tqdm import tqdm
# %matplotlib inline
import cv2

plt.ion()   # interactive mode
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Set random seem for reproducibility
manualSeed = 1234
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.cuda.manual_seed(manualSeed)

torch.torch.backends.cudnn.benchmark = True
torch.torch.backends.cudnn.enabled = True


'''
新しいフォルダを作成し、データセットをtrainとvalに振り分けるスクリプト

train -----n000001 
        |--n000002 
        |　…
        |　…
        |--n000009 

    ↓

train2------train-----n000001 
         |         |--n000002 
         |         |-- …
         |         |--n000009 
         |
         |---val------n000001 
                   |--n000002 
                   | 　…
                   |--n000009 
'''
# Out:
# Random Seed:  1234
# '\n新しいフォルダを作成し、データセットをtrainとvalに振り分けるスクリプト\n\ntrain -----n000001 \n        |--n000002 \n        |\u3000…\n        |\u3000…\n        |--n000009 \n\n    ↓\n\ntrain2------train-----n000001 \n         |         |--n000002 \n         |         |-- …\n         |         |--n000009 \n         |\n         |---val------n000001 \n                   |--n000002 \n                   | \u3000…\n                   |--n000009 \n'

# %% [markdown]
# # モジュール群

# %%
# 入力画像の前処理をするクラス
# 訓練時と推論時で処理が異なる

"""
    画像の前処理クラス。訓練時、検証時で異なる動作をする。
    画像のサイズをリサイズし、色を標準化する。
    訓練時はRandomResizedCropとRandomHorizontalFlipでデータオーギュメンテーションする。


    Attributes
    ----------
    resize : int
        リサイズ先の画像の大きさ。
    mean : (R, G, B)
        各色チャネルの平均値。
    std : (R, G, B)
        各色チャネルの標準偏差。
"""

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.75,1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(1.0,1.0)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'C:\\Datasets\\VGGface2\\train3'
n_samples = len(data_dir)

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")



print('number of classes: ' +str(len(class_names)))
'''
print(class_names)
k=0
for i in class_names:
    print(class_names[k]+"_train:"+str(len(os.listdir(path='C:\\Datasets\\VGGface2\\train3\\train\\'+class_names[k]))))
    k+=1
k=0
for i in class_names:
    print(class_names[k]+"_val:"+str(len(os.listdir(path='C:\\Datasets\\VGGface2\\train3\\val\\'+class_names[k]))))
    k+=1
'''
print("training data set_total："+ str(len(image_datasets['train'])))
print("validating data set_total："+str(len(image_datasets['val'])))


#少数の画像を可視化
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])


#Defining early stopping class
import numpy as np
import torch

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pt')
        self.val_loss_min = val_loss


#Train models
def train_model(model, criterion, optimizer, patience, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    # to track the training loss as the model trains
    train_loss = []
    # to track the validation loss as the model trains
    valid_loss = []


    # initialize the early_stopping object
    early_stopping = EarlyStopping(patience=patience, verbose=True)

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase] 
            
            # record train_loss and valid_loss
            if phase == 'train':
                train_loss.append(epoch_loss)
                print('epoch:{}'.format(epoch))
            if phase == 'val':
                valid_loss.append(epoch_loss)
            #print(train_loss)
            #print(valid_loss)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
      
      # early_stopping needs the validation loss to check if it has decresed, 
      # and if it has, it will make a checkpoint of the current model
        if phase == 'val':    
            early_stopping(epoch_loss, model)
                
            if early_stopping.early_stop:
                print("Early stopping")
                break
        print()


    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, train_loss, valid_loss


#Visualize model
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)
# Out:
# number of classes: 8
# training data set_total：1845
# validating data set_total：464

# %% [markdown]
# # Convnetの調整

# %%
# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet 

model_ft = EfficientNet.from_pretrained('efficientnet-b4')
num_ftrs = model_ft._fc.in_features
model_ft._fc = nn.Linear(num_ftrs, len(class_names))
#GPU使用
model_ft = model_ft.to(device)

#損失関数を定義
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#https://blog.knjcode.com/adabound-memo/
#https://pypi.org/project/torch-optimizer/
optimizer_ft = optim.AdaBound(
    model_ft.parameters(),
    lr= 1e-3,
    betas= (0.9, 0.999),
    final_lr = 0.1,
    gamma=1e-3,
    eps= 1e-8,
    weight_decay=0,
    amsbound=False,
)
# Out:
# Requirement already satisfied: efficientnet_pytorch in c:\users\ykita\appdata\local\programs\python\python37\lib\site-packages (0.6.3)
# Requirement already satisfied: torch in c:\users\ykita\appdata\local\programs\python\python37\lib\site-packages (from efficientnet_pytorch) (1.5.0)
# Requirement already satisfied: future in c:\users\ykita\appdata\local\programs\python\python37\lib\site-packages (from torch->efficientnet_pytorch) (0.18.2)
# Requirement already satisfied: numpy in c:\users\ykita\appdata\local\programs\python\python37\lib\site-packages (from torch->efficientnet_pytorch) (1.18.4)
# Loaded pretrained weights for efficientnet-b4

# %%
print(device)
# Out:
# cuda:0

# %%
#ネットワークの確認
print(model_ft)

from torchsummary import summary
model_ft = model_ft.to(device)
summary(model_ft, (3,224,224))
# Out:
# d-254          [-1, 672, 50, 50]           1,344
# MemoryEfficientSwish-255          [-1, 672, 50, 50]               0
#        ZeroPad2d-256          [-1, 672, 52, 52]               0
# Conv2dStaticSamePadding-257          [-1, 672, 50, 50]           6,048
#      BatchNorm2d-258          [-1, 672, 50, 50]           1,344
# MemoryEfficientSwish-259          [-1, 672, 50, 50]               0
#         Identity-260            [-1, 672, 1, 1]               0
# Conv2dStaticSamePadding-261             [-1, 28, 1, 1]          18,844
# MemoryEfficientSwish-262             [-1, 28, 1, 1]               0
#         Identity-263             [-1, 28, 1, 1]               0
# Conv2dStaticSamePadding-264            [-1, 672, 1, 1]          19,488
#         Identity-265          [-1, 672, 50, 50]               0
# Conv2dStaticSamePadding-266          [-1, 112, 50, 50]          75,264
#      BatchNorm2d-267          [-1, 112, 50, 50]             224
#      MBConvBlock-268          [-1, 112, 50, 50]               0
#         Identity-269          [-1, 112, 50, 50]               0
# Conv2dStaticSamePadding-270          [-1, 672, 50, 50]          75,264
#      BatchNorm2d-271          [-1, 672, 50, 50]           1,344
# MemoryEfficientSwish-272          [-1, 672, 50, 50]               0
#        ZeroPad2d-273          [-1, 672, 54, 54]               0
# Conv2dStaticSamePadding-274          [-1, 672, 50, 50]          16,800
#      BatchNorm2d-275          [-1, 672, 50, 50]           1,344
# MemoryEfficientSwish-276          [-1, 672, 50, 50]               0
#         Identity-277            [-1, 672, 1, 1]               0
# Conv2dStaticSamePadding-278             [-1, 28, 1, 1]          18,844
# MemoryEfficientSwish-279             [-1, 28, 1, 1]               0
#         Identity-280             [-1, 28, 1, 1]               0
# Conv2dStaticSamePadding-281            [-1, 672, 1, 1]          19,488
#         Identity-282          [-1, 672, 50, 50]               0
# Conv2dStaticSamePadding-283          [-1, 160, 50, 50]         107,520
#      BatchNorm2d-284          [-1, 160, 50, 50]             320
#      MBConvBlock-285          [-1, 160, 50, 50]               0
#         Identity-286          [-1, 160, 50, 50]               0
# Conv2dStaticSamePadding-287          [-1, 960, 50, 50]         153,600
#      BatchNorm2d-288          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-289          [-1, 960, 50, 50]               0
#        ZeroPad2d-290          [-1, 960, 54, 54]               0
# Conv2dStaticSamePadding-291          [-1, 960, 50, 50]          24,000
#      BatchNorm2d-292          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-293          [-1, 960, 50, 50]               0
#         Identity-294            [-1, 960, 1, 1]               0
# Conv2dStaticSamePadding-295             [-1, 40, 1, 1]          38,440
# MemoryEfficientSwish-296             [-1, 40, 1, 1]               0
#         Identity-297             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-298            [-1, 960, 1, 1]          39,360
#         Identity-299          [-1, 960, 50, 50]               0
# Conv2dStaticSamePadding-300          [-1, 160, 50, 50]         153,600
#      BatchNorm2d-301          [-1, 160, 50, 50]             320
#      MBConvBlock-302          [-1, 160, 50, 50]               0
#         Identity-303          [-1, 160, 50, 50]               0
# Conv2dStaticSamePadding-304          [-1, 960, 50, 50]         153,600
#      BatchNorm2d-305          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-306          [-1, 960, 50, 50]               0
#        ZeroPad2d-307          [-1, 960, 54, 54]               0
# Conv2dStaticSamePadding-308          [-1, 960, 50, 50]          24,000
#      BatchNorm2d-309          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-310          [-1, 960, 50, 50]               0
#         Identity-311            [-1, 960, 1, 1]               0
# Conv2dStaticSamePadding-312             [-1, 40, 1, 1]          38,440
# MemoryEfficientSwish-313             [-1, 40, 1, 1]               0
#         Identity-314             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-315            [-1, 960, 1, 1]          39,360
#         Identity-316          [-1, 960, 50, 50]               0
# Conv2dStaticSamePadding-317          [-1, 160, 50, 50]         153,600
#      BatchNorm2d-318          [-1, 160, 50, 50]             320
#      MBConvBlock-319          [-1, 160, 50, 50]               0
#         Identity-320          [-1, 160, 50, 50]               0
# Conv2dStaticSamePadding-321          [-1, 960, 50, 50]         153,600
#      BatchNorm2d-322          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-323          [-1, 960, 50, 50]               0
#        ZeroPad2d-324          [-1, 960, 54, 54]               0
# Conv2dStaticSamePadding-325          [-1, 960, 50, 50]          24,000
#      BatchNorm2d-326          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-327          [-1, 960, 50, 50]               0
#         Identity-328            [-1, 960, 1, 1]               0
# Conv2dStaticSamePadding-329             [-1, 40, 1, 1]          38,440
# MemoryEfficientSwish-330             [-1, 40, 1, 1]               0
#         Identity-331             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-332            [-1, 960, 1, 1]          39,360
#         Identity-333          [-1, 960, 50, 50]               0
# Conv2dStaticSamePadding-334          [-1, 160, 50, 50]         153,600
#      BatchNorm2d-335          [-1, 160, 50, 50]             320
#      MBConvBlock-336          [-1, 160, 50, 50]               0
#         Identity-337          [-1, 160, 50, 50]               0
# Conv2dStaticSamePadding-338          [-1, 960, 50, 50]         153,600
#      BatchNorm2d-339          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-340          [-1, 960, 50, 50]               0
#        ZeroPad2d-341          [-1, 960, 54, 54]               0
# Conv2dStaticSamePadding-342          [-1, 960, 50, 50]          24,000
#      BatchNorm2d-343          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-344          [-1, 960, 50, 50]               0
#         Identity-345            [-1, 960, 1, 1]               0
# Conv2dStaticSamePadding-346             [-1, 40, 1, 1]          38,440
# MemoryEfficientSwish-347             [-1, 40, 1, 1]               0
#         Identity-348             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-349            [-1, 960, 1, 1]          39,360
#         Identity-350          [-1, 960, 50, 50]               0
# Conv2dStaticSamePadding-351          [-1, 160, 50, 50]         153,600
#      BatchNorm2d-352          [-1, 160, 50, 50]             320
#      MBConvBlock-353          [-1, 160, 50, 50]               0
#         Identity-354          [-1, 160, 50, 50]               0
# Conv2dStaticSamePadding-355          [-1, 960, 50, 50]         153,600
#      BatchNorm2d-356          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-357          [-1, 960, 50, 50]               0
#        ZeroPad2d-358          [-1, 960, 54, 54]               0
# Conv2dStaticSamePadding-359          [-1, 960, 50, 50]          24,000
#      BatchNorm2d-360          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-361          [-1, 960, 50, 50]               0
#         Identity-362            [-1, 960, 1, 1]               0
# Conv2dStaticSamePadding-363             [-1, 40, 1, 1]          38,440
# MemoryEfficientSwish-364             [-1, 40, 1, 1]               0
#         Identity-365             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-366            [-1, 960, 1, 1]          39,360
#         Identity-367          [-1, 960, 50, 50]               0
# Conv2dStaticSamePadding-368          [-1, 160, 50, 50]         153,600
#      BatchNorm2d-369          [-1, 160, 50, 50]             320
#      MBConvBlock-370          [-1, 160, 50, 50]               0
#         Identity-371          [-1, 160, 50, 50]               0
# Conv2dStaticSamePadding-372          [-1, 960, 50, 50]         153,600
#      BatchNorm2d-373          [-1, 960, 50, 50]           1,920
# MemoryEfficientSwish-374          [-1, 960, 50, 50]               0
#        ZeroPad2d-375          [-1, 960, 53, 53]               0
# Conv2dStaticSamePadding-376          [-1, 960, 25, 25]          24,000
#      BatchNorm2d-377          [-1, 960, 25, 25]           1,920
# MemoryEfficientSwish-378          [-1, 960, 25, 25]               0
#         Identity-379            [-1, 960, 1, 1]               0
# Conv2dStaticSamePadding-380             [-1, 40, 1, 1]          38,440
# MemoryEfficientSwish-381             [-1, 40, 1, 1]               0
#         Identity-382             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-383            [-1, 960, 1, 1]          39,360
#         Identity-384          [-1, 960, 25, 25]               0
# Conv2dStaticSamePadding-385          [-1, 272, 25, 25]         261,120
#      BatchNorm2d-386          [-1, 272, 25, 25]             544
#      MBConvBlock-387          [-1, 272, 25, 25]               0
#         Identity-388          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-389         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-390         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-391         [-1, 1632, 25, 25]               0
#        ZeroPad2d-392         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-393         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-394         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-395         [-1, 1632, 25, 25]               0
#         Identity-396           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-397             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-398             [-1, 68, 1, 1]               0
#         Identity-399             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-400           [-1, 1632, 1, 1]         112,608
#         Identity-401         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-402          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-403          [-1, 272, 25, 25]             544
#      MBConvBlock-404          [-1, 272, 25, 25]               0
#         Identity-405          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-406         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-407         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-408         [-1, 1632, 25, 25]               0
#        ZeroPad2d-409         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-410         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-411         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-412         [-1, 1632, 25, 25]               0
#         Identity-413           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-414             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-415             [-1, 68, 1, 1]               0
#         Identity-416             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-417           [-1, 1632, 1, 1]         112,608
#         Identity-418         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-419          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-420          [-1, 272, 25, 25]             544
#      MBConvBlock-421          [-1, 272, 25, 25]               0
#         Identity-422          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-423         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-424         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-425         [-1, 1632, 25, 25]               0
#        ZeroPad2d-426         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-427         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-428         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-429         [-1, 1632, 25, 25]               0
#         Identity-430           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-431             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-432             [-1, 68, 1, 1]               0
#         Identity-433             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-434           [-1, 1632, 1, 1]         112,608
#         Identity-435         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-436          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-437          [-1, 272, 25, 25]             544
#      MBConvBlock-438          [-1, 272, 25, 25]               0
#         Identity-439          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-440         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-441         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-442         [-1, 1632, 25, 25]               0
#        ZeroPad2d-443         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-444         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-445         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-446         [-1, 1632, 25, 25]               0
#         Identity-447           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-448             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-449             [-1, 68, 1, 1]               0
#         Identity-450             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-451           [-1, 1632, 1, 1]         112,608
#         Identity-452         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-453          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-454          [-1, 272, 25, 25]             544
#      MBConvBlock-455          [-1, 272, 25, 25]               0
#         Identity-456          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-457         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-458         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-459         [-1, 1632, 25, 25]               0
#        ZeroPad2d-460         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-461         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-462         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-463         [-1, 1632, 25, 25]               0
#         Identity-464           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-465             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-466             [-1, 68, 1, 1]               0
#         Identity-467             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-468           [-1, 1632, 1, 1]         112,608
#         Identity-469         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-470          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-471          [-1, 272, 25, 25]             544
#      MBConvBlock-472          [-1, 272, 25, 25]               0
#         Identity-473          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-474         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-475         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-476         [-1, 1632, 25, 25]               0
#        ZeroPad2d-477         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-478         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-479         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-480         [-1, 1632, 25, 25]               0
#         Identity-481           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-482             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-483             [-1, 68, 1, 1]               0
#         Identity-484             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-485           [-1, 1632, 1, 1]         112,608
#         Identity-486         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-487          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-488          [-1, 272, 25, 25]             544
#      MBConvBlock-489          [-1, 272, 25, 25]               0
#         Identity-490          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-491         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-492         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-493         [-1, 1632, 25, 25]               0
#        ZeroPad2d-494         [-1, 1632, 29, 29]               0
# Conv2dStaticSamePadding-495         [-1, 1632, 25, 25]          40,800
#      BatchNorm2d-496         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-497         [-1, 1632, 25, 25]               0
#         Identity-498           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-499             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-500             [-1, 68, 1, 1]               0
#         Identity-501             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-502           [-1, 1632, 1, 1]         112,608
#         Identity-503         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-504          [-1, 272, 25, 25]         443,904
#      BatchNorm2d-505          [-1, 272, 25, 25]             544
#      MBConvBlock-506          [-1, 272, 25, 25]               0
#         Identity-507          [-1, 272, 25, 25]               0
# Conv2dStaticSamePadding-508         [-1, 1632, 25, 25]         443,904
#      BatchNorm2d-509         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-510         [-1, 1632, 25, 25]               0
#        ZeroPad2d-511         [-1, 1632, 27, 27]               0
# Conv2dStaticSamePadding-512         [-1, 1632, 25, 25]          14,688
#      BatchNorm2d-513         [-1, 1632, 25, 25]           3,264
# MemoryEfficientSwish-514         [-1, 1632, 25, 25]               0
#         Identity-515           [-1, 1632, 1, 1]               0
# Conv2dStaticSamePadding-516             [-1, 68, 1, 1]         111,044
# MemoryEfficientSwish-517             [-1, 68, 1, 1]               0
#         Identity-518             [-1, 68, 1, 1]               0
# Conv2dStaticSamePadding-519           [-1, 1632, 1, 1]         112,608
#         Identity-520         [-1, 1632, 25, 25]               0
# Conv2dStaticSamePadding-521          [-1, 448, 25, 25]         731,136
#      BatchNorm2d-522          [-1, 448, 25, 25]             896
#      MBConvBlock-523          [-1, 448, 25, 25]               0
#         Identity-524          [-1, 448, 25, 25]               0
# Conv2dStaticSamePadding-525         [-1, 2688, 25, 25]       1,204,224
#      BatchNorm2d-526         [-1, 2688, 25, 25]           5,376
# MemoryEfficientSwish-527         [-1, 2688, 25, 25]               0
#        ZeroPad2d-528         [-1, 2688, 27, 27]               0
# Conv2dStaticSamePadding-529         [-1, 2688, 25, 25]          24,192
#      BatchNorm2d-530         [-1, 2688, 25, 25]           5,376
# MemoryEfficientSwish-531         [-1, 2688, 25, 25]               0
#         Identity-532           [-1, 2688, 1, 1]               0
# Conv2dStaticSamePadding-533            [-1, 112, 1, 1]         301,168
# MemoryEfficientSwish-534            [-1, 112, 1, 1]               0
#         Identity-535            [-1, 112, 1, 1]               0
# Conv2dStaticSamePadding-536           [-1, 2688, 1, 1]         303,744
#         Identity-537         [-1, 2688, 25, 25]               0
# Conv2dStaticSamePadding-538          [-1, 448, 25, 25]       1,204,224
#      BatchNorm2d-539          [-1, 448, 25, 25]             896
#      MBConvBlock-540          [-1, 448, 25, 25]               0
#         Identity-541          [-1, 448, 25, 25]               0
# Conv2dStaticSamePadding-542         [-1, 1792, 25, 25]         802,816
#      BatchNorm2d-543         [-1, 1792, 25, 25]           3,584
# MemoryEfficientSwish-544         [-1, 1792, 25, 25]               0
# AdaptiveAvgPool2d-545           [-1, 1792, 1, 1]               0
#          Dropout-546                 [-1, 1792]               0
#           Linear-547                    [-1, 8]          14,344
# ================================================================
# Total params: 17,562,960
# Trainable params: 17,562,960
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 7.32
# Forward/backward pass size (MB): 6691.12
# Params size (MB): 67.00
# Estimated Total Size (MB): 6765.45
# ----------------------------------------------------------------

# %%
model_ft, train_loss, valid_loss = train_model(model_ft, criterion, optimizer_ft,  patience=10, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# epoch:0
# train Loss: 0.7799 Acc: 0.7561
# val Loss: 1.0638 Acc: 0.7974
# Validation loss decreased (inf --> 1.063795).  Saving model ...
#
# Epoch 1/99
# ----------
# epoch:1
# train Loss: 0.2573 Acc: 0.9182
# val Loss: 0.3488 Acc: 0.9073
# Validation loss decreased (1.063795 --> 0.348825).  Saving model ...
#
# Epoch 2/99
# ----------
# epoch:2
# train Loss: 0.1338 Acc: 0.9583
# val Loss: 0.0586 Acc: 0.9849
# Validation loss decreased (0.348825 --> 0.058649).  Saving model ...
#
# Epoch 3/99
# ----------
# epoch:3
# train Loss: 0.0700 Acc: 0.9767
# val Loss: 0.1016 Acc: 0.9655
# EarlyStopping counter: 1 out of 10
#
# Epoch 4/99
# ----------
# epoch:4
# train Loss: 0.0427 Acc: 0.9875
# val Loss: 0.0632 Acc: 0.9763
# EarlyStopping counter: 2 out of 10
#
# Epoch 5/99
# ----------
# epoch:5
# train Loss: 0.0419 Acc: 0.9881
# val Loss: 0.0621 Acc: 0.9806
# EarlyStopping counter: 3 out of 10
#
# Epoch 6/99
# ----------
# epoch:6
# train Loss: 0.0266 Acc: 0.9940
# val Loss: 0.0518 Acc: 0.9784
# Validation loss decreased (0.058649 --> 0.051777).  Saving model ...
#
# Epoch 7/99
# ----------
# epoch:7
# train Loss: 0.0323 Acc: 0.9908
# val Loss: 0.0696 Acc: 0.9784
# EarlyStopping counter: 1 out of 10
#
# Epoch 8/99
# ----------
# epoch:8
# train Loss: 0.0176 Acc: 0.9935
# val Loss: 0.0843 Acc: 0.9763
# EarlyStopping counter: 2 out of 10
#
# Epoch 9/99
# ----------
# epoch:9
# train Loss: 0.0202 Acc: 0.9951
# val Loss: 0.1036 Acc: 0.9720
# EarlyStopping counter: 3 out of 10
#
# Epoch 10/99
# ----------
# epoch:10
# train Loss: 0.0095 Acc: 0.9984
# val Loss: 0.0622 Acc: 0.9871
# EarlyStopping counter: 4 out of 10
#
# Epoch 11/99
# ----------
# epoch:11
# train Loss: 0.0116 Acc: 0.9962
# val Loss: 0.0954 Acc: 0.9828
# EarlyStopping counter: 5 out of 10
#
# Epoch 12/99
# ----------
# epoch:12
# train Loss: 0.0131 Acc: 0.9957
# val Loss: 0.0854 Acc: 0.9849
# EarlyStopping counter: 6 out of 10
#
# Epoch 13/99
# ----------
# epoch:13
# train Loss: 0.0074 Acc: 0.9978
# val Loss: 0.0822 Acc: 0.9849
# EarlyStopping counter: 7 out of 10
#
# Epoch 14/99
# ----------
# epoch:14
# train Loss: 0.0085 Acc: 0.9978
# val Loss: 0.0613 Acc: 0.9871
# EarlyStopping counter: 8 out of 10
#
# Epoch 15/99
# ----------
# epoch:15
# train Loss: 0.0093 Acc: 0.9967
# val Loss: 0.0474 Acc: 0.9849
# Validation loss decreased (0.051777 --> 0.047355).  Saving model ...
#
# Epoch 16/99
# ----------
# epoch:16
# train Loss: 0.0087 Acc: 0.9962
# val Loss: 0.0703 Acc: 0.9806
# EarlyStopping counter: 1 out of 10
#
# Epoch 17/99
# ----------
# epoch:17
# train Loss: 0.0145 Acc: 0.9951
# val Loss: 0.0550 Acc: 0.9849
# EarlyStopping counter: 2 out of 10
#
# Epoch 18/99
# ----------
# epoch:18
# train Loss: 0.0075 Acc: 0.9978
# val Loss: 0.0631 Acc: 0.9806
# EarlyStopping counter: 3 out of 10
#
# Epoch 19/99
# ----------
# epoch:19
# train Loss: 0.0047 Acc: 0.9984
# val Loss: 0.0608 Acc: 0.9784
# EarlyStopping counter: 4 out of 10
#
# Epoch 20/99
# ----------
# epoch:20
# train Loss: 0.0053 Acc: 0.9978
# val Loss: 0.0760 Acc: 0.9741
# EarlyStopping counter: 5 out of 10
#
# Epoch 21/99
# ----------
# epoch:21
# train Loss: 0.0058 Acc: 0.9978
# val Loss: 0.0759 Acc: 0.9784
# EarlyStopping counter: 6 out of 10
#
# Epoch 22/99
# ----------
# epoch:22
# train Loss: 0.0037 Acc: 0.9989
# val Loss: 0.0829 Acc: 0.9828
# EarlyStopping counter: 7 out of 10
#
# Epoch 23/99
# ----------
# epoch:23
# train Loss: 0.0051 Acc: 0.9978
# val Loss: 0.0614 Acc: 0.9871
# EarlyStopping counter: 8 out of 10
#
# Epoch 24/99
# ----------
# epoch:24
# train Loss: 0.0035 Acc: 0.9984
# val Loss: 0.0905 Acc: 0.9806
# EarlyStopping counter: 9 out of 10
#
# Epoch 25/99
# ----------
# epoch:25
# train Loss: 0.0043 Acc: 0.9995
# val Loss: 0.0511 Acc: 0.9914
# EarlyStopping counter: 10 out of 10
# Early stopping
# Training complete in 36m 41s
# Best val Acc: 0.991379
